# %%
x<-c(10,45,30,50,35)

# %%
x
# Out:
# [1] 10 45 30 50 35

# %%
y<-x>30

# %%
y
# Out:
# [1] FALSE  TRUE FALSE  TRUE  TRUE

# %%
x<-c(10,45,30,50,35)
y<-x>30&x<40

# %%
y
# Out:
# [1] FALSE FALSE FALSE FALSE  TRUE

# %%
x<-c(10,45,30,50,35)
y<-c(20,15,25,65,5)

# %%
x<y
# Out:
# [1]  TRUE FALSE FALSE  TRUE FALSE

# %%
x<-c(10,45,30,50,35)
y<-c(20,15,25,65,5)
x>30
# Out:
# [1] FALSE  TRUE FALSE  TRUE  TRUE

# %%
x<-c(10,45,30,50,35)
y<-c(20,15,25,65,5)
which(x>30)
# Out:
# [1] 2 4 5

# %%
x<-c(10,45,30,50,35)
y<-c(20,15,25,65,5)
x[which(x>30)]
# Out:
# [1] 45 50 35
